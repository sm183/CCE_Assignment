# %% [markdown]
# <a href="https://colab.research.google.com/github/sm183/CCE_Assignment/blob/main/Mobile_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('mobile_usage_behavioral_analysis.csv')
df
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56    Male                   2.61                     7.15
# 1          2   46    Male                   2.13                    13.79
# 2          3   32  Female                   7.28                     4.50
# 3          4   25  Female                   1.20                     6.29
# 4          5   38    Male                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41  Female                   3.58                    12.46
# 996      997   32    Male                   9.65                    10.51
# 997      998   46  Female                  11.68                    10.06
# 998      999   25    Male                   3.89                    10.78
# 999     1000   22  Female                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   User_ID                       1000 non-null   int64
#  1   Age                           1000 non-null   int64
#  2   Gender                        1000 non-null   object
#  3   Total_App_Usage_Hours         1000 non-null   float64
#  4   Daily_Screen_Time_Hours       1000 non-null   float64
#  5   Number_of_Apps_Used           1000 non-null   int64
#  6   Social_Media_Usage_Hours      1000 non-null   float64
#  7   Productivity_App_Usage_Hours  1000 non-null   float64
#  8   Gaming_App_Usage_Hours        1000 non-null   float64
#  9   Location                      1000 non-null   object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.3+ KB

# %%
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})
df
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56       0                   2.61                     7.15
# 1          2   46       0                   2.13                    13.79
# 2          3   32       1                   7.28                     4.50
# 3          4   25       1                   1.20                     6.29
# 4          5   38       0                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41       1                   3.58                    12.46
# 996      997   32       0                   9.65                    10.51
# 997      998   46       1                  11.68                    10.06
# 998      999   25       0                   3.89                    10.78
# 999     1000   22       1                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 50    37
# 43    34
# 52    32
# 54    31
# 45    30
# 22    29
# 56    28
# 42    27
# 41    27
# 25    27
# 18    27
# 19    27
# 49    26
# 23    25
# 40    25
# 53    25
# 20    25
# 31    24
# 47    24
# 34    24
# 39    24
# 29    23
# 46    23
# 57    23
# 28    23
# 32    22
# 33    21
# 36    21
# 21    21
# 26    21
# 38    20
# 27    20
# 30    20
# 55    20
# 58    19
# 51    19
# 59    19
# 37    19
# 48    18
# 44    18
# 35    17
# 24    15
# Name: count, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# New York       243
# Phoenix        199
# Chicago        192
# Los Angeles    185
# Houston        181
# Name: count, dtype: int64

# %%
df['Location'] = df['Location'].map({'New York': 0,'Phoenix': 1,'Chicago': 2,'Los Angeles': 3,'Houston': 4})
df
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56       0                   2.61                     7.15
# 1          2   46       0                   2.13                    13.79
# 2          3   32       1                   7.28                     4.50
# 3          4   25       1                   1.20                     6.29
# 4          5   38       0                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41       1                   3.58                    12.46
# 996      997   32       0                   9.65                    10.51
# 997      998   46       1                  11.68                    10.06
# 998      999   25       0                   3.89                    10.78
# 999     1000   22       1                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5e038_row0_col0, #T_5e038_row1_col1, #T_5e038_row2_col2, #T_5e038_row3_col3, #T_5e038_row4_col4, #T_5e038_row5_col5, #T_5e038_row6_col6, #T_5e038_row7_col7, #T_5e038_row8_col8, #T_5e038_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5e038_row0_col1, #T_5e038_row0_col9, #T_5e038_row1_col4, #T_5e038_row2_col4, #T_5e038_row2_col5, #T_5e038_row3_col8, #T_5e038_row4_col2, #T_5e038_row6_col7, #T_5e038_row7_col2, #T_5e038_row7_col5, #T_5e038_row7_col6, #T_5e038_row8_col3, #T_5e038_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5e038_row0_col2, #T_5e038_row0_col4, #T_5e038_row3_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_5e038_row0_col3, #T_5e038_row1_col8, #T_5e038_row2_col7, #T_5e038_row4_col8, #T_5e038_row7_col3, #T_5e038_row9_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5e038_row0_col5, #T_5e038_row1_col5, #T_5e038_row8_col4 {
#   background-color: #3c4ec2;
# ...

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#            User_ID          Age  Total_App_Usage_Hours  \
# count  1000.000000  1000.000000            1000.000000
# mean    500.500000    38.745000               6.405670
# std     288.819436    12.186734               3.134855
# min       1.000000    18.000000               1.000000
# 25%     250.750000    28.000000               3.590000
# 50%     500.500000    40.000000               6.455000
# 75%     750.250000    50.000000               9.122500
# max    1000.000000    59.000000              11.970000
#
#        Daily_Screen_Time_Hours  Number_of_Apps_Used  Social_Media_Usage_Hours  \
# count              1000.000000           1000.00000               1000.000000
# mean                  7.696310             16.64700                  2.456330
# std                   3.714187              7.61961                  1.439525
# min                   1.010000              3.00000                  0.000000
# ...

# %%
#multi-label classification : gender and age group
